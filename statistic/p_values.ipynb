# %% [markdown]
# Statistical Significance

# %% [markdown]
# ![image.png](attachment:521a536e-ab16-4344-b809-f7c17aa1adcc.png)
#
# h0 - Moeda só tem Cara
#
# h1 - Moeda não tem só Cara
#
# Temos que para acontecer coroa uma vez é de 0.5, acontecer 2 vezes é de 0.25, 3 vezes 0.12, 4 vezes 0.06, 5 vezes 0.03 e 6 vezes 0.01

# %% [markdown]
# ![image.png](attachment:ff4a06f3-2692-431c-825c-ffaa36242bea.png)
# Se chegar na probabilidade de menos que 0.06, podemos afirmar com 95% de confiança que h0 (hip nula é rejeitada)
