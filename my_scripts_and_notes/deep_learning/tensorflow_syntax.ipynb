# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
df = pd.read_csv("TensorFlow_FILES/TensorFlow_FILES/DATA/fake_reg.csv")

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %% [markdown]
# ### Simple visual analyze

# %%
sns.pairplot(df)

# %% [markdown]
# It is simple to notate that there is a relation between price and feature 2 because they improve together

# %%
from sklearn.model_selection import train_test_split

# %%
# different than we are accustomed,
#when we are using DL, we have to use numpy matrix form instead of pandas form
X = df[["feature1","feature2"]].values
X
# Out:
# array([[ 999.78755752,  999.7660962 ],
#        [ 998.86161491, 1001.04240315],
#        [1000.07026691,  998.84401463],
#        ...,
#        [1001.45164617,  998.84760554],
#        [1000.77102275,  998.56285086],
#        [ 999.2322436 , 1001.45140713]])

# %%
y = df[["price"]].values
y
# obs when a feature is undimencional, we will use a lower case, thus y must be in lower case
# Out:
# array([[461.52792939],
#        [548.13001146],
#        [410.29716167],
#        [540.38221981],
#        [546.02455292],
#        [542.9836716 ],
#        [555.48566416],
#        [417.56972453],
#        [373.14653122],
#        [633.35029248],
#        [624.24709206],
#        [475.37241721],
#        [600.36844486],
#        [532.83295175],
#        [472.8353628 ],
#        [506.31229096],
#        [508.414406  ],
#        [610.4553519 ],
#        [323.65776198],
#        [446.21230389],
#        [362.12270299],
#        [433.41064026],
#        [562.00257647],
#        [637.30962074],
#        [522.80800754],
#        [469.8028243 ],
#        [543.10992778],
#        [565.43416994],
#        [530.03285381],
#        [610.58016503],
#        [482.55641188],
#        [327.56004052],
#        [579.73083872],
#        [448.42981468],
#        [628.97709187],
#        [536.79737216],
#        [570.06729543],
#        [357.82557519],
#        [612.08492732],
#        [444.67970846],
# ...

# %%
# Tip: copy and past from documentation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_test.shape
# Out:
# (300, 2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
help(MinMaxScaler)
# Out:
# Help on class MinMaxScaler in module sklearn.preprocessing._data:
#
# class MinMaxScaler(sklearn.base.TransformerMixin, sklearn.base.BaseEstimator)
#  |  MinMaxScaler(feature_range=(0, 1), *, copy=True)
#  |
#  |  Transform features by scaling each feature to a given range.
#  |
#  |  This estimator scales and translates each feature individually such
#  |  that it is in the given range on the training set, e.g. between
#  |  zero and one.
#  |
#  |  The transformation is given by::
#  |
#  |      X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#  |      X_scaled = X_std * (max - min) + min
#  |
#  |  where min, max = feature_range.
#  |
#  |  This transformation is often used as an alternative to zero mean,
#  |  unit variance scaling.
#  |
#  |  Read more in the :ref:`User Guide <preprocessing_scaler>`.
#  |
#  |  Parameters
#  |  ----------
#  |  feature_range : tuple (min, max), default=(0, 1)
#  |      Desired range of transformed data.
#  |
# ...

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.max()
# Out:
# 1.0

# %%
X_train.min()
# Out:
# 0.0
